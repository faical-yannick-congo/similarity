# %%
import iprPy
import duplicates
from copy import deepcopy

import numpy as np
import pandas as pd

# %%
record_style = 'calculation_relax_static'

# %% [markdown]
# Load database and records of a given style

# %%
#database = iprPy.load_database('master')
database = iprPy.load_database(style='local', host='database')

records_df = database.get_records_df(style=record_style, flat=True, full=False)

# %% [markdown]
# Get record-specific terms

# %%
record = iprPy.load_record(style=record_style)
dterms = record.compare_terms
fterms = {}
for key in record.compare_fterms:
    fterms[key] = 1e-4

# %% [markdown]
# Create possibly new calculation records

# %%
baserecord = database.get_record(style=record_style, name=records_df.key[0])
basedict = baserecord.todict(full=False, flat=True)

tests = []
# Vary size multipliers
for i in range(1, 6, 1):
    vals = deepcopy(basedict)
    vals['a_mult2'] = i
    vals['b_mult2'] = i
    vals['c_mult2'] = i
    tests.append(vals)

# Vary temperatures
for i in range(5):
    vals = deepcopy(basedict)
    vals['temperature'] = i * 50.0 + 1e-5
    tests.append(vals)
tests = pd.DataFrame(tests)

tests
# Out:
#   LAMMPS_version  a_mult1  a_mult2  b_mult1  b_mult2  c_mult1  c_mult2  error  \
# 0    22 Aug 2018        0        1        0        1        0        1    NaN
# 1    22 Aug 2018        0        2        0        2        0        2    NaN
# 2    22 Aug 2018        0        3        0        3        0        3    NaN
# 3    22 Aug 2018        0        4        0        4        0        4    NaN
# 4    22 Aug 2018        0        5        0        5        0        5    NaN
# 5    22 Aug 2018        0        1        0        1        0        1    NaN
# 6    22 Aug 2018        0        1        0        1        0        1    NaN
# 7    22 Aug 2018        0        1        0        1        0        1    NaN
# 8    22 Aug 2018        0        1        0        1        0        1    NaN
# 9    22 Aug 2018        0        1        0        1        0        1    NaN
#
#         family iprPy_version     ...      pressure_xx pressure_xy pressure_xz  \
# 0  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 1  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 2  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 3  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 4  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 5  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 6  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 7  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 8  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 9  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
#
#   pressure_yy pressure_yz pressure_zz             script    status  symbols  \
# 0         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 1         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 2         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 3         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 4         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 5         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 6         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 7         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 8         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 9         0.0         0.0         0.0  calc_relax_static  finished       Ti
#
#    temperature
# 0      0.00000
# 1      0.00000
# 2      0.00000
# 3      0.00000
# 4      0.00000
# 5      0.00001
# 6     50.00001
# 7    100.00001
# 8    150.00001
# 9    200.00001
#
# [10 rows x 28 columns]

# %% [markdown]
# Identify test records that are not duplicates of existing records

# %%
def new_calculations(old, test, dterms, fterms):
    old_count = len(old)
    allrecords = pd.concat([old, test], ignore_index=True)
    
    if 'a_mult' in dterms:
        allrecords['a_mult'] = allrecords.a_mult2 - allrecords.a_mult1
    if 'b_mult' in dterms:
        allrecords['b_mult'] = allrecords.b_mult2 - allrecords.b_mult1
    if 'c_mult' in dterms:
        allrecords['c_mult'] = allrecords.c_mult2 - allrecords.c_mult1
    
    isdup = duplicates.duplicates_allclose(allrecords, dterms, fterms)
    print(np.sum(isdup[:old_count]), 'duplicates found in old records')
    print(np.sum(isdup[old_count:]), 'duplicates found in new records')

    isnew = ~isdup[old_count:].values
    return tests[isnew]

# %%
new_calculations(records_df, tests, dterms, fterms)
# Out:
# 0 duplicates found in old records
# 2 duplicates found in new records
#   LAMMPS_version  a_mult1  a_mult2  b_mult1  b_mult2  c_mult1  c_mult2  error  \
# 1    22 Aug 2018        0        2        0        2        0        2    NaN
# 2    22 Aug 2018        0        3        0        3        0        3    NaN
# 3    22 Aug 2018        0        4        0        4        0        4    NaN
# 4    22 Aug 2018        0        5        0        5        0        5    NaN
# 6    22 Aug 2018        0        1        0        1        0        1    NaN
# 7    22 Aug 2018        0        1        0        1        0        1    NaN
# 8    22 Aug 2018        0        1        0        1        0        1    NaN
# 9    22 Aug 2018        0        1        0        1        0        1    NaN
#
#         family iprPy_version     ...      pressure_xx pressure_xy pressure_xz  \
# 1  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 2  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 3  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 4  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 6  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 7  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 8  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
# 9  A1--Cu--fcc         0.8.3     ...              0.0         0.0         0.0
#
#   pressure_yy pressure_yz pressure_zz             script    status  symbols  \
# 1         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 2         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 3         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 4         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 6         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 7         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 8         0.0         0.0         0.0  calc_relax_static  finished       Ti
# 9         0.0         0.0         0.0  calc_relax_static  finished       Ti
#
#    temperature
# 1      0.00000
# 2      0.00000
# 3      0.00000
# 4      0.00000
# 6     50.00001
# 7    100.00001
# 8    150.00001
# 9    200.00001
#
# [8 rows x 28 columns]
